# %% [markdown]
# # Exercise 6 - Logical XOR

# %% [markdown]
# - Add one more neuron in the hidden layer and compute the output matrix
#   - See how values are reshaped in hidden layer and how it impacts the output
